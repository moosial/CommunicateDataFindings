# %%
# load the csv
import pandas as pd
df=pd.read_csv('prosperLoanData.csv')

# %%
len(df)
# Out:
# 113937

# %%
df.head(200)
# Out:
#                   ListingKey  ListingNumber            ListingCreationDate  \
# 0    1021339766868145413AB3B         193129  2007-08-26 19:09:29.263000000
# 1    10273602499503308B223C1        1209647  2014-02-27 08:28:07.900000000
# 2    0EE9337825851032864889A          81716  2007-01-05 15:00:47.090000000
# 3    0EF5356002482715299901A         658116  2012-10-22 11:02:35.010000000
# 4    0F023589499656230C5E3E2         909464  2013-09-14 18:38:39.097000000
# 5    0F05359734824199381F61D        1074836  2013-12-14 08:26:37.093000000
# 6    0F0A3576754255009D63151         750899  2013-04-12 09:52:56.147000000
# 7    0F1035772717087366F9EA7         768193  2013-05-05 06:49:27.493000000
# 8    0F043596202561788EA13D5        1023355  2013-12-02 10:43:39.117000000
# 9    0F043596202561788EA13D5        1023355  2013-12-02 10:43:39.117000000
# 10   0F123545674891886D9F106         587746  2012-05-10 07:04:01.577000000
# ...

# %%
df.ListingKey.nunique()
# Out:
# 113066

# %%
df.ListingNumber.nunique()
# Out:
# 113066

# %%
df_2 = df[df.duplicated(subset=['ListingKey', 'ListingNumber'])]
#

# Select all duplicate rows based on multiple column names in list
#duplicateRowsDF = dfObj[dfObj.duplicated(['Age', 'City'])]

# %%
df_2[df_2.duplicated(subset=['ListingKey', 'ListingNumber'])]
# Out:
#                      ListingKey  ListingNumber            ListingCreationDate  \
# 12780   5DB83600871174699C124B4        1114591  2014-01-16 11:16:58.077000000
# 20289   5A2F35875117483773421B0         875616  2013-08-21 07:25:22.360000000
# 20569   17A93590655669644DB4C06         951186  2013-10-02 17:20:16.550000000
# 31450   17A93590655669644DB4C06         951186  2013-10-02 17:20:16.550000000
# 37941   349D3587495831350F0F648         882888  2013-08-28 20:31:41.107000000
# 38619   47C1359638497431975670B        1057901  2013-12-06 11:44:58.283000000
# 42750   17A93590655669644DB4C06         951186  2013-10-02 17:20:16.550000000
# 42751   17A93590655669644DB4C06         951186  2013-10-02 17:20:16.550000000
# 52383   1CF43590627610277373CFE         956166  2013-10-03 20:09:45.413000000
# 53552   FC5F3592110384244FC7BA7         961598  2013-10-17 19:00:53.250000000
# 55187   DE8535960513435199406CE        1056749  2013-12-06 05:43:13.830000000
# ...

# %%
df3 = df_2.query('ListingNumber == "951186"')

# %%
df3.duplicated()
# Out:
# 14888    False
# 20569    False
# 31450    False
# 42750    False
# 42751    False
# dtype: bool

# %%
# dataframe["period"] = dataframe["Year"].map(str) + dataframe["quarter"]
df['listing'] = df['ListingKey'] + "-" + df['ListingNumber'].map(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113937 entries, 0 to 113936
# Data columns (total 82 columns):
# ListingKey                             113937 non-null object
# ListingNumber                          113937 non-null int64
# ListingCreationDate                    113937 non-null object
# CreditGrade                            28953 non-null object
# Term                                   113937 non-null int64
# LoanStatus                             113937 non-null object
# ClosedDate                             55089 non-null object
# BorrowerAPR                            113912 non-null float64
# BorrowerRate                           113937 non-null float64
# LenderYield                            113937 non-null float64
# EstimatedEffectiveYield                84853 non-null float64
# EstimatedLoss                          84853 non-null float64
# EstimatedReturn                        84853 non-null float64
# ...

# %%
df.sort_values(by=('listing'))
df.listing.duplicated
# Out:
# <bound method Series.duplicated of 0          1021339766868145413AB3B-193129
# 1         10273602499503308B223C1-1209647
# 2           0EE9337825851032864889A-81716
# 3          0EF5356002482715299901A-658116
# 4          0F023589499656230C5E3E2-909464
# 5         0F05359734824199381F61D-1074836
# 6          0F0A3576754255009D63151-750899
# 7          0F1035772717087366F9EA7-768193
# 8         0F043596202561788EA13D5-1023355
# 9         0F043596202561788EA13D5-1023355
# 10         0F123545674891886D9F106-587746
# 11         0F1734025150298088A5F2B-213551
# 12        0F1A3597143888805163EF7-1081604
# 13         0F1C3583260311305D68F87-840820
# 14         0F353575943675863D1AFC0-757359
# 15         0F483544120452347F48121-577164
# 16         0F4835843081468212F0892-841846
# 17          0FDF336575182398852A8DC-31540
# 18         0FF2357105361877390B58D-716058
# 19         0FFC35866018516621B0D3F-875565
# 20        101635959323992333B3C70-1011916
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113937 entries, 0 to 113936
# Data columns (total 82 columns):
# ListingKey                             113937 non-null object
# ListingNumber                          113937 non-null int64
# ListingCreationDate                    113937 non-null object
# CreditGrade                            28953 non-null object
# Term                                   113937 non-null int64
# LoanStatus                             113937 non-null object
# ClosedDate                             55089 non-null object
# BorrowerAPR                            113912 non-null float64
# BorrowerRate                           113937 non-null float64
# LenderYield                            113937 non-null float64
# EstimatedEffectiveYield                84853 non-null float64
# EstimatedLoss                          84853 non-null float64
# EstimatedReturn                        84853 non-null float64
# ...

# %%
df.LoanKey.duplicated().sum()
# Out:
# 871

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.ListingKey.duplicated().sum()
# Out:
# 871

# %%
df.LoanNumber.duplicated().sum()
# Out:
# 871

# %%
attr = pd.read_csv('Attributes_Selected.csv')

# %%
attr
# Out:
#                              Attributes
# 0                         ListingNumber
# 1                   ListingCreationDate
# 2                   LoanOriginationDate
# 3                             MemberKey
# 4                       Loan Attributes
# 5                       ListingCategory
# 6                           BorrowerAPR
# 7                          BorrowerRate
# 8               ProsperRating (numeric)
# 9                 ProsperRating (Alpha)
# 10                         ProsperScore
# 11                                 Term
# 12                           LoanStatus
# 13                           ClosedDate
# 14                   LoanOriginalAmount
# 15                   MonthlyLoanPayment
# 16                        PercentFunded
# 17           InvestmentFromFriendsCount
# 18          InvestmentFromFriendsAmount
# 19                            Investors
# 20                    DebtToIncomeRatio
# 21                          IncomeRange
# ...

# %%
str = '   1 2 3    '
str.replace(' ', '')
# Out:
# '123'

# %%
df.Term.value_counts()
# Out:
# 36    87778
# 60    24545
# 12     1614
# Name: Term, dtype: int64
